# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from transformers import ViTFeatureExtractor, TFViTForImageClassification, DetrFeatureExtractor, DetrForObjectDetection
from transformers import CLIPProcessor, CLIPModel
from PIL import Image
import numpy as np
import cv2

# %% [markdown]
# ### 11.4.1 분류를 위한 트랜스포머

# %%
# ViT 프로그래밍 실습 1
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

n_class = 10
img_size = (32, 32, 3)

patch_size = 4
p2 = (img_size[0]//patch_size) ** 2

d_model = 64
h = 8
N = 6


class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.p_size = patch_size
        
    def call(self, img):
        batch_size = tf.shape(img)[0]
        patches = tf.image.extract_patches(images=img, sizes=[1, self.p_size, self.p_size, 1], 
                                           strides=[1, self.p_size, self.p_size, 1], rates=[1, 1, 1, 1],
                                          padding="VALID")
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

    
class PatchEncoder(layers.Layer):
    def __init__(self, p2, d_model):
        super(PatchEncoder, self).__init__()
        self.p2 = p2
        self.projection = layers.Dense(units=d_model)
        self.positional_embedding=layers.Embedding(input_dim=p2, output_dim=d_model)
        
    def call(self, patch):
        positions = tf.range(start=0, limit=self.p2, delta=1)
        encoded = self.projection(patch) + self.positional_embedding(positions)
        return encoded
    

def create_vit_classifier():
    inputs = layers.Input(shape=(img_size))
    nor = layers.Normalization()(inputs)
    
    patches = Patches(patch_size)(nor)
    x = PatchEncoder(p2, d_model)(patches)
    
    for _ in range(N):
        x1 = layers.LayerNormalization(epsilon=1e-6)(x)
        x2 = layers.MultiHeadAttention(num_heads=h, key_dim=d_model//h, dropout=0.1)(x1, x1)
        x3 = layers.Add()([x2, x])
        x4 = layers.LayerNormalization(epsilon=1e-6)(x3)
        x5 = layers.Dense(d_model*2, activation=tf.nn.gelu)(x4)
        x6 = layers.Dropout(0.1)(x5)
        x7 = layers.Dense(d_model, activation=tf.nn.gelu)(x6)
        x8 = layers.Dropout(0.1)(x7)
        x = layers.Add()([x8, x3])
        
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    x = layers.Flatten()(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(2048, activation=tf.nn.gelu)(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(1024, activation=tf.nn.gelu)(x)
    x = layers.Dropout(0.5)(x)
    output = layers.Dense(n_class, activation="softmax")(x)
    
    model = keras.models.Model(inputs, output)
    return model


model =create_vit_classifier()
model.layers[1].adapt(x_train)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  normalization_3 (Normalization  (None, 32, 32, 3)   7           ['input_4[0][0]']
#  )
#
#  patches_3 (Patches)            (None, None, 48)     0           ['normalization_3[0][0]']
#
#  patch_encoder_3 (PatchEncoder)  (None, 64, 64)      7232        ['patches_3[0][0]']
#
#  layer_normalization_15 (LayerN  (None, 64, 64)      128         ['patch_encoder_3[0][0]']
#  ormalization)
#
#  multi_head_attention_8 (MultiH  (None, 64, 64)      16640       ['layer_normalization_15[0][0]',
#  eadAttention)                                                    'layer_normalization_15[0][0]']
#
#  add_13 (Add)                   (None, 64, 64)       0           ['multi_head_attention_8[0][0]',
#                                                                   'patch_encoder_3[0][0]']
#
#  layer_normalization_16 (LayerN  (None, 64, 64)      128         ['add_13[0][0]']
#  ormalization)
#
#  dense_19 (Dense)               (None, 64, 128)      8320        ['layer_normalization_16[0][0]']
#
#  dropout_15 (Dropout)           (None, 64, 128)      0           ['dense_19[0][0]']
#
#  dense_20 (Dense)               (None, 64, 64)       8256        ['dropout_15[0][0]']
#
#  dropout_16 (Dropout)           (None, 64, 64)       0           ['dense_20[0][0]']
#
#  add_14 (Add)                   (None, 64, 64)       0           ['dropout_16[0][0]',
#                                                                   'add_13[0][0]']
#
#  layer_normalization_17 (LayerN  (None, 64, 64)      128         ['add_14[0][0]']
#  ormalization)
#
#  multi_head_attention_9 (MultiH  (None, 64, 64)      16640       ['layer_normalization_17[0][0]',
#  eadAttention)                                                    'layer_normalization_17[0][0]']
#
#  add_15 (Add)                   (None, 64, 64)       0           ['multi_head_attention_9[0][0]',
#                                                                   'add_14[0][0]']
#
#  layer_normalization_18 (LayerN  (None, 64, 64)      128         ['add_15[0][0]']
#  ormalization)
#
#  dense_21 (Dense)               (None, 64, 128)      8320        ['layer_normalization_18[0][0]']
#
#  dropout_17 (Dropout)           (None, 64, 128)      0           ['dense_21[0][0]']
#
#  dense_22 (Dense)               (None, 64, 64)       8256        ['dropout_17[0][0]']
#
#  dropout_18 (Dropout)           (None, 64, 64)       0           ['dense_22[0][0]']
#
#  add_16 (Add)                   (None, 64, 64)       0           ['dropout_18[0][0]',
#                                                                   'add_15[0][0]']
#
#  layer_normalization_19 (LayerN  (None, 64, 64)      128         ['add_16[0][0]']
#  ormalization)
#
#  multi_head_attention_10 (Multi  (None, 64, 64)      16640       ['layer_normalization_19[0][0]',
#  HeadAttention)                                                   'layer_normalization_19[0][0]']
#
#  add_17 (Add)                   (None, 64, 64)       0           ['multi_head_attention_10[0][0]',
#                                                                   'add_16[0][0]']
#
#  layer_normalization_20 (LayerN  (None, 64, 64)      128         ['add_17[0][0]']
#  ormalization)
#
#  dense_23 (Dense)               (None, 64, 128)      8320        ['layer_normalization_20[0][0]']
#
#  dropout_19 (Dropout)           (None, 64, 128)      0           ['dense_23[0][0]']
#
#  dense_24 (Dense)               (None, 64, 64)       8256        ['dropout_19[0][0]']
#
#  dropout_20 (Dropout)           (None, 64, 64)       0           ['dense_24[0][0]']
#
#  add_18 (Add)                   (None, 64, 64)       0           ['dropout_20[0][0]',
#                                                                   'add_17[0][0]']
#
#  layer_normalization_21 (LayerN  (None, 64, 64)      128         ['add_18[0][0]']
#  ormalization)
#
#  multi_head_attention_11 (Multi  (None, 64, 64)      16640       ['layer_normalization_21[0][0]',
#  HeadAttention)                                                   'layer_normalization_21[0][0]']
#
#  add_19 (Add)                   (None, 64, 64)       0           ['multi_head_attention_11[0][0]',
#                                                                   'add_18[0][0]']
#
#  layer_normalization_22 (LayerN  (None, 64, 64)      128         ['add_19[0][0]']
#  ormalization)
#
#  dense_25 (Dense)               (None, 64, 128)      8320        ['layer_normalization_22[0][0]']
#
#  dropout_21 (Dropout)           (None, 64, 128)      0           ['dense_25[0][0]']
#
#  dense_26 (Dense)               (None, 64, 64)       8256        ['dropout_21[0][0]']
#
#  dropout_22 (Dropout)           (None, 64, 64)       0           ['dense_26[0][0]']
#
#  add_20 (Add)                   (None, 64, 64)       0           ['dropout_22[0][0]',
#                                                                   'add_19[0][0]']
#
#  layer_normalization_23 (LayerN  (None, 64, 64)      128         ['add_20[0][0]']
#  ormalization)
#
#  multi_head_attention_12 (Multi  (None, 64, 64)      16640       ['layer_normalization_23[0][0]',
#  HeadAttention)                                                   'layer_normalization_23[0][0]']
#
#  add_21 (Add)                   (None, 64, 64)       0           ['multi_head_attention_12[0][0]',
#                                                                   'add_20[0][0]']
#
#  layer_normalization_24 (LayerN  (None, 64, 64)      128         ['add_21[0][0]']
#  ormalization)
#
#  dense_27 (Dense)               (None, 64, 128)      8320        ['layer_normalization_24[0][0]']
#
#  dropout_23 (Dropout)           (None, 64, 128)      0           ['dense_27[0][0]']
#
#  dense_28 (Dense)               (None, 64, 64)       8256        ['dropout_23[0][0]']
#
#  dropout_24 (Dropout)           (None, 64, 64)       0           ['dense_28[0][0]']
#
#  add_22 (Add)                   (None, 64, 64)       0           ['dropout_24[0][0]',
#                                                                   'add_21[0][0]']
#
#  layer_normalization_25 (LayerN  (None, 64, 64)      128         ['add_22[0][0]']
#  ormalization)
#
#  multi_head_attention_13 (Multi  (None, 64, 64)      16640       ['layer_normalization_25[0][0]',
#  HeadAttention)                                                   'layer_normalization_25[0][0]']
#
#  add_23 (Add)                   (None, 64, 64)       0           ['multi_head_attention_13[0][0]',
#                                                                   'add_22[0][0]']
#
#  layer_normalization_26 (LayerN  (None, 64, 64)      128         ['add_23[0][0]']
#  ormalization)
#
#  dense_29 (Dense)               (None, 64, 128)      8320        ['layer_normalization_26[0][0]']
#
#  dropout_25 (Dropout)           (None, 64, 128)      0           ['dense_29[0][0]']
#
#  dense_30 (Dense)               (None, 64, 64)       8256        ['dropout_25[0][0]']
#
#  dropout_26 (Dropout)           (None, 64, 64)       0           ['dense_30[0][0]']
#
#  add_24 (Add)                   (None, 64, 64)       0           ['dropout_26[0][0]',
#                                                                   'add_23[0][0]']
#
#  layer_normalization_27 (LayerN  (None, 64, 64)      128         ['add_24[0][0]']
#  ormalization)
#
#  flatten_1 (Flatten)            (None, 4096)         0           ['layer_normalization_27[0][0]']
#
#  dropout_27 (Dropout)           (None, 4096)         0           ['flatten_1[0][0]']
#
#  dense_31 (Dense)               (None, 2048)         8390656     ['dropout_27[0][0]']
#
#  dropout_28 (Dropout)           (None, 2048)         0           ['dense_31[0][0]']
#
#  dense_32 (Dense)               (None, 1024)         2098176     ['dropout_28[0][0]']
#
#  dropout_29 (Dropout)           (None, 1024)         0           ['dense_32[0][0]']
#
#  dense_33 (Dense)               (None, 10)           10250       ['dropout_29[0][0]']
#
# ==================================================================================================
# Total params: 10,707,281
# Trainable params: 10,707,274
# Non-trainable params: 7
# __________________________________________________________________________________________________

# %%
# ViT 프로그래밍 실습 1
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

n_class = 10
img_size = (32, 32, 3)
img_expand_size = (72, 72, 3)

patch_size = 4
p2 = (img_expand_size[0]//patch_size) ** 2

d_model = 64
h = 8
N = 6


class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.p_size = patch_size
        
    def call(self, img):
        batch_size = tf.shape(img)[0]
        patches = tf.image.extract_patches(images=img, sizes=[1, self.p_size, self.p_size, 1], 
                                           strides=[1, self.p_size, self.p_size, 1], rates=[1, 1, 1, 1],
                                          padding="VALID")
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

    
class PatchEncoder(layers.Layer):
    def __init__(self, p2, d_model):
        super(PatchEncoder, self).__init__()
        self.p2 = p2
        self.projection = layers.Dense(units=d_model)
        self.positional_embedding=layers.Embedding(input_dim=p2, output_dim=d_model)
        
    def call(self, patch):
        positions = tf.range(start=0, limit=self.p2, delta=1)
        encoded = self.projection(patch) + self.positional_embedding(positions)
        return encoded
    

def create_vit_classifier():
    inputs = layers.Input(shape=(img_size))
    nor = layers.Normalization()(inputs)
    exp = layers.Resizing(img_expand_size[0], img_expand_size[1])(nor)
    
    x = layers.RandomFlip('horizontal')(exp)
    x = layers.RandomRotation(factor=0.02)(x)
    x = layers.RandomZoom(height_factor=0.2, width_factor=0.2)(x)
    
    patches = Patches(patch_size)(x)
    x = PatchEncoder(p2, d_model)(patches)
    
    for _ in range(N):
        x1 = layers.LayerNormalization(epsilon=1e-6)(x)
        x2 = layers.MultiHeadAttention(num_heads=h, key_dim=d_model//h, dropout=0.1)(x1, x1)
        x3 = layers.Add()([x2, x])
        x4 = layers.LayerNormalization(epsilon=1e-6)(x3)
        x5 = layers.Dense(d_model*2, activation=tf.nn.gelu)(x4)
        x6 = layers.Dropout(0.1)(x5)
        x7 = layers.Dense(d_model, activation=tf.nn.gelu)(x6)
        x8 = layers.Dropout(0.1)(x7)
        x = layers.Add()([x8, x3])
        
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    x = layers.Flatten()(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(2048, activation=tf.nn.gelu)(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(1024, activation=tf.nn.gelu)(x)
    x = layers.Dropout(0.5)(x)
    output = layers.Dense(n_class, activation="softmax")(x)
    
    model = keras.models.Model(inputs, output)
    return model


model =create_vit_classifier()
model.layers[1].adapt(x_train)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  normalization_4 (Normalization  (None, 32, 32, 3)   7           ['input_5[0][0]']
#  )
#
#  resizing (Resizing)            (None, 72, 72, 3)    0           ['normalization_4[0][0]']
#
#  random_flip (RandomFlip)       (None, 72, 72, 3)    0           ['resizing[0][0]']
#
#  random_rotation (RandomRotatio  (None, 72, 72, 3)   0           ['random_flip[0][0]']
#  n)
#
#  random_zoom (RandomZoom)       (None, 72, 72, 3)    0           ['random_rotation[0][0]']
#
#  patches_4 (Patches)            (None, None, 48)     0           ['random_zoom[0][0]']
#
#  patch_encoder_4 (PatchEncoder)  (None, 324, 64)     23872       ['patches_4[0][0]']
#
#  layer_normalization_28 (LayerN  (None, 324, 64)     128         ['patch_encoder_4[0][0]']
#  ormalization)
#
#  multi_head_attention_14 (Multi  (None, 324, 64)     16640       ['layer_normalization_28[0][0]',
#  HeadAttention)                                                   'layer_normalization_28[0][0]']
#
#  add_25 (Add)                   (None, 324, 64)      0           ['multi_head_attention_14[0][0]',
#                                                                   'patch_encoder_4[0][0]']
#
#  layer_normalization_29 (LayerN  (None, 324, 64)     128         ['add_25[0][0]']
#  ormalization)
#
#  dense_35 (Dense)               (None, 324, 128)     8320        ['layer_normalization_29[0][0]']
#
#  dropout_30 (Dropout)           (None, 324, 128)     0           ['dense_35[0][0]']
#
#  dense_36 (Dense)               (None, 324, 64)      8256        ['dropout_30[0][0]']
#
#  dropout_31 (Dropout)           (None, 324, 64)      0           ['dense_36[0][0]']
#
#  add_26 (Add)                   (None, 324, 64)      0           ['dropout_31[0][0]',
#                                                                   'add_25[0][0]']
#
#  layer_normalization_30 (LayerN  (None, 324, 64)     128         ['add_26[0][0]']
#  ormalization)
#
#  multi_head_attention_15 (Multi  (None, 324, 64)     16640       ['layer_normalization_30[0][0]',
#  HeadAttention)                                                   'layer_normalization_30[0][0]']
#
#  add_27 (Add)                   (None, 324, 64)      0           ['multi_head_attention_15[0][0]',
#                                                                   'add_26[0][0]']
#
#  layer_normalization_31 (LayerN  (None, 324, 64)     128         ['add_27[0][0]']
#  ormalization)
#
#  dense_37 (Dense)               (None, 324, 128)     8320        ['layer_normalization_31[0][0]']
#
#  dropout_32 (Dropout)           (None, 324, 128)     0           ['dense_37[0][0]']
#
#  dense_38 (Dense)               (None, 324, 64)      8256        ['dropout_32[0][0]']
#
#  dropout_33 (Dropout)           (None, 324, 64)      0           ['dense_38[0][0]']
#
#  add_28 (Add)                   (None, 324, 64)      0           ['dropout_33[0][0]',
#                                                                   'add_27[0][0]']
#
#  layer_normalization_32 (LayerN  (None, 324, 64)     128         ['add_28[0][0]']
#  ormalization)
#
#  multi_head_attention_16 (Multi  (None, 324, 64)     16640       ['layer_normalization_32[0][0]',
#  HeadAttention)                                                   'layer_normalization_32[0][0]']
#
#  add_29 (Add)                   (None, 324, 64)      0           ['multi_head_attention_16[0][0]',
#                                                                   'add_28[0][0]']
#
#  layer_normalization_33 (LayerN  (None, 324, 64)     128         ['add_29[0][0]']
#  ormalization)
#
#  dense_39 (Dense)               (None, 324, 128)     8320        ['layer_normalization_33[0][0]']
#
#  dropout_34 (Dropout)           (None, 324, 128)     0           ['dense_39[0][0]']
#
#  dense_40 (Dense)               (None, 324, 64)      8256        ['dropout_34[0][0]']
#
#  dropout_35 (Dropout)           (None, 324, 64)      0           ['dense_40[0][0]']
#
#  add_30 (Add)                   (None, 324, 64)      0           ['dropout_35[0][0]',
#                                                                   'add_29[0][0]']
#
#  layer_normalization_34 (LayerN  (None, 324, 64)     128         ['add_30[0][0]']
#  ormalization)
#
#  multi_head_attention_17 (Multi  (None, 324, 64)     16640       ['layer_normalization_34[0][0]',
#  HeadAttention)                                                   'layer_normalization_34[0][0]']
#
#  add_31 (Add)                   (None, 324, 64)      0           ['multi_head_attention_17[0][0]',
#                                                                   'add_30[0][0]']
#
#  layer_normalization_35 (LayerN  (None, 324, 64)     128         ['add_31[0][0]']
#  ormalization)
#
#  dense_41 (Dense)               (None, 324, 128)     8320        ['layer_normalization_35[0][0]']
#
#  dropout_36 (Dropout)           (None, 324, 128)     0           ['dense_41[0][0]']
#
#  dense_42 (Dense)               (None, 324, 64)      8256        ['dropout_36[0][0]']
#
#  dropout_37 (Dropout)           (None, 324, 64)      0           ['dense_42[0][0]']
#
#  add_32 (Add)                   (None, 324, 64)      0           ['dropout_37[0][0]',
#                                                                   'add_31[0][0]']
#
#  layer_normalization_36 (LayerN  (None, 324, 64)     128         ['add_32[0][0]']
#  ormalization)
#
#  multi_head_attention_18 (Multi  (None, 324, 64)     16640       ['layer_normalization_36[0][0]',
#  HeadAttention)                                                   'layer_normalization_36[0][0]']
#
#  add_33 (Add)                   (None, 324, 64)      0           ['multi_head_attention_18[0][0]',
#                                                                   'add_32[0][0]']
#
#  layer_normalization_37 (LayerN  (None, 324, 64)     128         ['add_33[0][0]']
#  ormalization)
#
#  dense_43 (Dense)               (None, 324, 128)     8320        ['layer_normalization_37[0][0]']
#
#  dropout_38 (Dropout)           (None, 324, 128)     0           ['dense_43[0][0]']
#
#  dense_44 (Dense)               (None, 324, 64)      8256        ['dropout_38[0][0]']
#
#  dropout_39 (Dropout)           (None, 324, 64)      0           ['dense_44[0][0]']
#
#  add_34 (Add)                   (None, 324, 64)      0           ['dropout_39[0][0]',
#                                                                   'add_33[0][0]']
#
#  layer_normalization_38 (LayerN  (None, 324, 64)     128         ['add_34[0][0]']
#  ormalization)
#
#  multi_head_attention_19 (Multi  (None, 324, 64)     16640       ['layer_normalization_38[0][0]',
#  HeadAttention)                                                   'layer_normalization_38[0][0]']
#
#  add_35 (Add)                   (None, 324, 64)      0           ['multi_head_attention_19[0][0]',
#                                                                   'add_34[0][0]']
#
#  layer_normalization_39 (LayerN  (None, 324, 64)     128         ['add_35[0][0]']
#  ormalization)
#
#  dense_45 (Dense)               (None, 324, 128)     8320        ['layer_normalization_39[0][0]']
#
#  dropout_40 (Dropout)           (None, 324, 128)     0           ['dense_45[0][0]']
#
#  dense_46 (Dense)               (None, 324, 64)      8256        ['dropout_40[0][0]']
#
#  dropout_41 (Dropout)           (None, 324, 64)      0           ['dense_46[0][0]']
#
#  add_36 (Add)                   (None, 324, 64)      0           ['dropout_41[0][0]',
#                                                                   'add_35[0][0]']
#
#  layer_normalization_40 (LayerN  (None, 324, 64)     128         ['add_36[0][0]']
#  ormalization)
#
#  flatten_2 (Flatten)            (None, 20736)        0           ['layer_normalization_40[0][0]']
#
#  dropout_42 (Dropout)           (None, 20736)        0           ['flatten_2[0][0]']
#
#  dense_47 (Dense)               (None, 2048)         42469376    ['dropout_42[0][0]']
#
#  dropout_43 (Dropout)           (None, 2048)         0           ['dense_47[0][0]']
#
#  dense_48 (Dense)               (None, 1024)         2098176     ['dropout_43[0][0]']
#
#  dropout_44 (Dropout)           (None, 1024)         0           ['dense_48[0][0]']
#
#  dense_49 (Dense)               (None, 10)           10250       ['dropout_44[0][0]']
#
# ==================================================================================================
# Total params: 44,802,641
# Trainable params: 44,802,634
# Non-trainable params: 7
# __________________________________________________________________________________________________

# %% [markdown]
# ### 11.5.1 ViT 프로그래밍 실습: 영상 분류

# %%
img = [Image.open("./imgs/BSDS_242078.jpg"), Image.open("./imgs/BSDS_361010.jpg"), 
       Image.open("./imgs/BSDS_376001.jpg")]

feature_extractor = ViTFeatureExtractor.from_pretrained("google/vit-base-patch16-224")
model = TFViTForImageClassification.from_pretrained("google/vit-base-patch16-224")

inputs = feature_extractor(img, return_tesors="tf")
res = model(**inputs)

for i in range(res.logits.shape[0]):
    plt.imshow(img[i])
    plt.axis("off")
    plt.show()
    predicted_label = int(tf.math.argmax(res.logits[i], axis=-1))
    prob=float(tf.nn.softmax(res.logits[i])[predcited_label]*100.0)
    print(i, "번 째, 영상의 1순위 분류: ", model.config.id2label[predicted_label], prob)

# %% [markdown]
# ### 11.5.2 DETR 프로그래밍 실습: 물체 검출

# %%
img = Image.open("./imgs/BSDS_361010.jpg")

feature_extractor = DetrFeatureExtractor.from_pretrained("facebook/detr-resnet-50")
model = DetrForObjectDetection.from_pretrained("facebook/detr-resent-50")

inputs = feature_extractor(img, return_tensors='pt')
res = model(**inputs)

colors = np.random.uniform(0, 255, size=(100, 3))
im = cv2.cvtColor(np.array(img), cv2.COLO_BGR2RGB)
for i in range(res.logits.shape[0]):
    predicted_label = res.logits[0, i].argmax(-1).item()
    if predicted_label != 91:
        name = model.config.id2label[predicted_label]
        prob = "{:.2f}".format(float(res.logits[0,i].softmax(dim=0)[predicted_label]))
        cx, cy = int(481*res.pred_boxes[0,i,0]), int(321*res.pred_boxes[0,i,1])
        w,h = int(481*res.pred_boxes[0,i,2]), int(321*res.pred_boxes[0,i,3])
        cv2.rectangle(im, (cx-w//2, cy-h//2), (cx+w//2, cy+h//2), colors[predicted_label], 2)
        cv2.putText(im, name+str(prob), (cx-w//2, cy-h//2-5), cv2.FONT_HERSHEY_SIMPLEX, 0.6, colors[predicted+label], 1)
        
cv2.imshow("DETR", im)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ### 11.5.3 CLIP

# %%
img = Image.open("./imgs/BSDS_361010.jpg")

processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")

captions = ["Two horses are running on grass", "Students are eating", "Croquet palying on horese",
           "Golf playing on horses"]
inputs = processor(text=captions, images=img, return_tensors='pt', padding=True)
res = model(**inputs)

plt.imshow(img)
plt.axis("off")
plt.show()

logits = res.logits_per_image
probs = logits.softmax(dim=1)

for i in range(len(captions)):
    print(captions[i], ": ", "{:.2f}".format(float(probs[0,i]*100.0)))
